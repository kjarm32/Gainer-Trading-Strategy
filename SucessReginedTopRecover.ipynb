# %%
# File: enhanced_stock_trading_strategy_v4_debug_fixed.py

import alpaca_trade_api as tradeapi
import pandas as pd
from datetime import datetime, timedelta
from config import API_KEY, SECRET_KEY, BASE_URL

# Initialize Alpaca API
api = tradeapi.REST(API_KEY, SECRET_KEY, BASE_URL, api_version='v2')

# Expanded stock and ETF symbols list
symbols = [
    # Mega-cap tech
    'AAPL', 'MSFT', 'AMZN', 'GOOG', 'META', 'TSLA', 'NVDA', 'AMD',

    # Large-cap growth and momentum stocks
    'NFLX', 'SHOP', 'SQ', 'PYPL', 'ROKU', 'SPOT', 'UBER', 'LYFT', 'ZM', 'BABA',

    # Semiconductor and tech equipment
    'ASML', 'TXN', 'QCOM', 'AVGO', 'INTC', 'MU', 'LRCX', 'MRVL',

    # Fintech and digital payment companies
    'V', 'MA', 'AXP', 'INTU', 'COIN', 'AFRM', 'SOFI', 'FISV',

    # Consumer discretionary and e-commerce
    'HD', 'LOW', 'COST', 'WMT', 'TGT', 'NKE', 'LULU', 'SBUX', 'MCD',

    # Industrial and infrastructure
    'CAT', 'DE', 'MMM', 'UNP', 'BA', 'GE', 'HON',

    # Energy and alternative energy
    'XOM', 'CVX', 'SLB', 'PLUG', 'RUN', 'ENPH', 'FSLR', 'SPWR',

    # Healthcare and biotechnology
    'JNJ', 'PFE', 'MRK', 'LLY', 'ABBV', 'BIIB', 'GILD', 'REGN', 'VRTX', 'BNTX',

    # Retail and e-commerce
    'AMZN', 'WMT', 'EBAY', 'ETSY', 'CHWY', 'JD', 'MELI',

    # Financials and banks
    'JPM', 'GS', 'MS', 'BAC', 'C', 'WFC', 'BLK', 'SCHW', 'TROW',

    # Telecom and media
    'T', 'VZ', 'DIS', 'CMCSA', 'TMUS', 'NFLX', 'DISCA', 'PARA',

    # Precious metals and materials
    'NEM', 'FCX', 'CLF', 'VALE', 'BHP', 'RIO',

    # ETFs (growth, tech, semiconductors, leveraged ETFs)
    'TQQQ', 'SOXL', 'SPY', 'QQQ', 'DIA', 'ARKK', 'ARKG', 'ARKF', 'SMH', 'XLF', 'XLE',

    # International large caps
    'BABA', 'TCEHY', 'NIO', 'TSM', 'INFY', 'SAP', 'RY', 'TD'
]

# Define ETFs subset
etfs = {'TQQQ', 'SOXL', 'SPY', 'QQQ', 'DIA', 'ARKK', 'ARKG', 'ARKF', 'SMH', 'XLF', 'XLE'}

# Define date range and settings
timeframe = tradeapi.TimeFrame.Day
start_date = '2023-08-19'
end_date = '2024-08-19'
start_date_dt = datetime.strptime(start_date, '%Y-%m-%d') - timedelta(days=50)
end_date_dt = datetime.strptime(end_date, '%Y-%m-%d')

# Fetch stock data
bars = api.get_bars(
    symbols, timeframe,
    start=start_date_dt.strftime('%Y-%m-%d'),
    end=end_date_dt.strftime('%Y-%m-%d')
).df.sort_index()

# Detect drop days with adjusted thresholds
def detect_drop_days(bars, drop_threshold_low=-6, drop_threshold_high=-1):
    bars['percent_change'] = bars['close'].pct_change() * 100
    drop_days = bars[(bars['percent_change'] <= drop_threshold_high) & (bars['percent_change'] >= drop_threshold_low)]
    print(f"Detected {len(drop_days)} drop days")  # Debugging line
    return drop_days

# Refined trading strategy with relaxed entry criteria
def apply_trading_strategy(bars, drop_days, max_allocation_per_trade=0.20, stop_loss_threshold=-2.0, take_profit_threshold=2.5, etf_trailing_stop=2.5):
    initial_balance = 100000
    balance = initial_balance
    open_positions = []
    trade_log = []

    print(f"Starting balance: ${initial_balance}")

    for index, drop_day in drop_days.iterrows():
        symbol = drop_day['symbol']
        drop_date = index
        symbol_bars = bars[bars['symbol'] == symbol]
        post_drop_data = symbol_bars.loc[drop_date:]

        # Entry based on any green day after a drop
        if len(post_drop_data) > 1:
            day_1 = post_drop_data.iloc[1]
            if day_1['close'] > day_1['open']:
                entry_price = day_1['open']
                available_cash = balance * max_allocation_per_trade
                shares_to_buy = available_cash // entry_price
                trade_value = shares_to_buy * entry_price

                if trade_value <= balance:
                    trailing_stop = etf_trailing_stop if symbol in etfs else stop_loss_threshold
                    open_positions.append({
                        'symbol': symbol,
                        'entry_price': entry_price,
                        'shares': shares_to_buy,
                        'initial_date': drop_date,
                        'trade_value': trade_value,
                        'trailing_stop_price': entry_price * (1 - trailing_stop / 100),
                        'take_profit_price': entry_price * (1 + take_profit_threshold / 100),
                        'has_reentered': False
                    })
                    balance -= trade_value
                    print(f"Entered {symbol} at {entry_price} on {drop_date} with {shares_to_buy} shares, "
                          f"remaining balance: ${balance:.2f}")

        # Manage open positions
        for day in range(2, len(post_drop_data)):
            day_data = post_drop_data.iloc[day]
            current_price = day_data['close']
            for position in open_positions[:]:
                if position['symbol'] == symbol:
                    profit_loss_pct = ((current_price - position['entry_price']) / position['entry_price']) * 100

                    # Trailing stop adjustment
                    if current_price > position['entry_price']:
                        new_trailing_stop = current_price * (1 - (etf_trailing_stop if symbol in etfs else stop_loss_threshold) / 100)
                        position['trailing_stop_price'] = max(position['trailing_stop_price'], new_trailing_stop)
                        print(f"Updated trailing stop for {symbol} to ${position['trailing_stop_price']:.2f}")

                    # Exit condition check
                    if current_price <= position['trailing_stop_price']:
                        balance += current_price * position['shares']
                        trade_log.append({
                            'symbol': symbol,
                            'entry_date': position['initial_date'],
                            'exit_date': day_data.name,
                            'profit_loss_pct': profit_loss_pct,
                            'exit_reason': 'Trailing Stop or Stop-Loss Hit'
                        })
                        open_positions.remove(position)
                        print(f"Exited {symbol} at {current_price} on {day_data.name} due to trailing stop, "
                              f"new balance: ${balance:.2f}")

                    elif current_price >= position['take_profit_price']:
                        balance += current_price * position['shares']
                        trade_log.append({
                            'symbol': symbol,
                            'entry_date': position['initial_date'],
                            'exit_date': day_data.name,
                            'profit_loss_pct': profit_loss_pct,
                            'exit_reason': 'Take Profit Hit'
                        })
                        open_positions.remove(position)
                        print(f"Exited {symbol} at {current_price} on {day_data.name} due to take profit, "
                              f"new balance: ${balance:.2f}")

                    elif day == 3:
                        balance += current_price * position['shares']
                        trade_log.append({
                            'symbol': symbol,
                            'entry_date': position['initial_date'],
                            'exit_date': day_data.name,
                            'profit_loss_pct': profit_loss_pct,
                            'exit_reason': 'Day 3 Exit'
                        })
                        open_positions.remove(position)
                        print(f"Exited {symbol} at {current_price} on {day_data.name} due to Day 3 Exit, "
                              f"new balance: ${balance:.2f}")

    final_balance = balance + sum(p['shares'] * post_drop_data.iloc[-1]['close'] for p in open_positions)
    return_percentage = ((final_balance - initial_balance) / initial_balance) * 100

    print(f"Final portfolio value: ${final_balance:.2f}")
    print(f"Return percentage: {return_percentage:.2f}%")
    print("Trade log:")
    for trade in trade_log:
        print(trade)

# Detect drop days
drop_days = detect_drop_days(bars)

# Apply the refined trading strategy
apply_trading_strategy(bars, drop_days)
# Out:
# Detected 390 drop days
# Starting balance: $100000
# Entered BABA at 83.98 on 2023-07-03 04:00:00+00:00 with 238.0 shares, remaining balance: $80012.76
# Exited BABA at 83.84 on 2023-07-06 04:00:00+00:00 due to trailing stop, new balance: $99966.68
# Entered TQQQ at 41.83 on 2023-07-11 04:00:00+00:00 with 477.0 shares, remaining balance: $80013.77
# Updated trailing stop for TQQQ to $42.96
# Exited TQQQ at 44.06 on 2023-07-13 04:00:00+00:00 due to take profit, new balance: $101030.39
# Entered JPM at 148.7 on 2023-07-12 04:00:00+00:00 with 135.0 shares, remaining balance: $80955.89
# Updated trailing stop for JPM to $152.77
# Exited JPM at 149.77 on 2023-07-14 04:00:00+00:00 due to trailing stop, new balance: $101174.84
# Entered AXP at 172.94 on 2023-07-14 04:00:00+00:00 with 117.0 shares, remaining balance: $80940.86
# Updated trailing stop for AXP to $181.60
# Exited AXP at 178.04 on 2023-07-18 04:00:00+00:00 due to trailing stop, new balance: $101771.54
# Entered JPM at 150.35 on 2023-07-14 04:00:00+00:00 with 135.0 shares, remaining balance: $81474.29
# Updated trailing stop for JPM to $156.73
# Exited JPM at 153.66 on 2023-07-18 04:00:00+00:00 due to trailing stop, new balance: $102218.39
# Entered HON at 205.57 on 2023-07-14 04:00:00+00:00 with 99.0 shares, remaining balance: $81866.96
# Exited HON at 205.25 on 2023-07-18 04:00:00+00:00 due to trailing stop, new balance: $102186.71
# Entered CMCSA at 41.99 on 2023-07-17 04:00:00+00:00 with 486.0 shares, remaining balance: $81779.57
# Updated trailing stop for CMCSA to $43.56
# Exited CMCSA at 42.71 on 2023-07-19 04:00:00+00:00 due to trailing stop, new balance: $102536.63
# Entered MS at 94.01 on 2023-07-21 04:00:00+00:00 with 218.0 shares, remaining balance: $82042.45
# Updated trailing stop for MS to $96.31
# Exited MS at 94.42 on 2023-07-25 04:00:00+00:00 due to trailing stop, new balance: $102626.01
# Entered BA at 212.06 on 2023-07-21 04:00:00+00:00 with 96.0 shares, remaining balance: $82268.25
# Updated trailing stop for BA to $218.40
# Exited BA at 214.12 on 2023-07-25 04:00:00+00:00 due to trailing stop, new balance: $102823.77
# Entered SMH at 154.46 on 2023-07-24 04:00:00+00:00 with 133.0 shares, remaining balance: $82280.59
# Updated trailing stop for SMH to $150.81
# Updated trailing stop for SMH to $153.52
# Exited SMH at 157.46 on 2023-07-27 04:00:00+00:00 due to Day 3 Exit, new balance: $103222.77
# Entered SAP at 132.11 on 2023-07-24 04:00:00+00:00 with 156.0 shares, remaining balance: $82613.61
# Updated trailing stop for SAP to $134.99
# Exited SAP at 132.34 on 2023-07-26 04:00:00+00:00 due to trailing stop, new balance: $103258.65
# Entered BHP at 63.44 on 2023-07-24 04:00:00+00:00 with 325.0 shares, remaining balance: $82640.65
# Exited BHP at 63.12 on 2023-07-26 04:00:00+00:00 due to trailing stop, new balance: $103154.65
# Entered AAPL at 194.67 on 2023-07-27 04:00:00+00:00 with 105.0 shares, remaining balance: $82714.30
# Updated trailing stop for AAPL to $200.38
# Exited AAPL at 196.45 on 2023-07-31 04:00:00+00:00 due to trailing stop, new balance: $103341.55
# Entered FCX at 44.09 on 2023-07-28 04:00:00+00:00 with 468.0 shares, remaining balance: $82707.43
# Exited FCX at 43.75 on 2023-08-01 04:00:00+00:00 due to trailing stop, new balance: $103182.43
# Entered MS at 88.84 on 2023-08-02 04:00:00+00:00 with 232.0 shares, remaining balance: $82571.55
# Exited MS at 88.79 on 2023-08-04 04:00:00+00:00 due to trailing stop, new balance: $103170.83
# Entered VALE at 13.73 on 2023-08-04 04:00:00+00:00 with 1502.0 shares, remaining balance: $82548.37
# Updated trailing stop for VALE to $14.03
# Exited VALE at 13.75 on 2023-08-08 04:00:00+00:00 due to trailing stop, new balance: $103200.87
# Entered RY at 94.8 on 2023-08-10 04:00:00+00:00 with 217.0 shares, remaining balance: $82629.27
# Exited RY at 94.27 on 2023-08-14 04:00:00+00:00 due to trailing stop, new balance: $103085.86
# Entered JNJ at 172.86 on 2023-08-16 04:00:00+00:00 with 119.0 shares, remaining balance: $82515.52
# Exited JNJ at 172.49 on 2023-08-18 04:00:00+00:00 due to trailing stop, new balance: $103041.83
# Entered NKE at 103.83 on 2023-08-17 04:00:00+00:00 with 198.0 shares, remaining balance: $82483.49
# Exited NKE at 102.86 on 2023-08-21 04:00:00+00:00 due to trailing stop, new balance: $102849.77
# Entered SBUX at 96.01 on 2023-08-17 04:00:00+00:00 with 214.0 shares, remaining balance: $82303.63
# Updated trailing stop for SBUX to $98.39
# Exited SBUX at 96.46 on 2023-08-21 04:00:00+00:00 due to trailing stop, new balance: $102946.07
# Entered MMM at 106.8 on 2023-09-01 04:00:00+00:00 with 192.0 shares, remaining balance: $82440.47
# Exited MMM at 106.37 on 2023-09-06 04:00:00+00:00 due to trailing stop, new balance: $102863.51
# Entered V at 245.42 on 2023-09-05 04:00:00+00:00 with 83.0 shares, remaining balance: $82493.65
# Updated trailing stop for V to $252.08
# Exited V at 247.14 on 2023-09-07 04:00:00+00:00 due to trailing stop, new balance: $103006.27
# Entered INTC at 36.56 on 2023-09-05 04:00:00+00:00 with 563.0 shares, remaining balance: $82422.99
# Updated trailing stop for INTC to $38.94
# Exited INTC at 38.18 on 2023-09-07 04:00:00+00:00 due to trailing stop, new balance: $103918.33
# Entered GE at 111.5 on 2023-09-07 04:00:00+00:00 with 186.0 shares, remaining balance: $83179.33
# Updated trailing stop for GE to $116.55
# Exited GE at 114.26 on 2023-09-11 04:00:00+00:00 due to trailing stop, new balance: $104431.69
# Entered AXP at 157.65 on 2023-09-11 04:00:00+00:00 with 132.0 shares, remaining balance: $83621.89
# Updated trailing stop for AXP to $162.32
# Exited AXP at 159.14 on 2023-09-13 04:00:00+00:00 due to trailing stop, new balance: $104628.37
# Entered GS at 333.5 on 2023-09-12 04:00:00+00:00 with 62.0 shares, remaining balance: $83951.37
# Updated trailing stop for GS to $351.46
# Exited GS at 344.57 on 2023-09-14 04:00:00+00:00 due to trailing stop, new balance: $105314.71
# Entered AMD at 105.1 on 2023-09-12 04:00:00+00:00 with 200.0 shares, remaining balance: $84294.71
# Updated trailing stop for AMD to $108.76
# Exited AMD at 106.63 on 2023-09-14 04:00:00+00:00 due to trailing stop, new balance: $105620.71
# Entered CLF at 13.96 on 2023-09-18 04:00:00+00:00 with 1513.0 shares, remaining balance: $84499.23
# Updated trailing stop for CLF to $14.72
# Exited CLF at 14.43 on 2023-09-20 04:00:00+00:00 due to trailing stop, new balance: $106331.82
# Entered SBUX at 93.43 on 2023-09-21 04:00:00+00:00 with 227.0 shares, remaining balance: $85123.21
# Exited SBUX at 92.74 on 2023-09-25 04:00:00+00:00 due to trailing stop, new balance: $106175.19
# Entered QQQ at 356.93 on 2023-09-22 04:00:00+00:00 with 59.0 shares, remaining balance: $85116.32
# Exited QQQ at 355.04 on 2023-09-27 04:00:00+00:00 due to Day 3 Exit, new balance: $106063.68
# Entered TMUS at 140.01 on 2023-09-25 04:00:00+00:00 with 151.0 shares, remaining balance: $84922.17
# Exited TMUS at 139.7 on 2023-09-27 04:00:00+00:00 due to trailing stop, new balance: $106016.87
# Entered FSLR at 151.4 on 2023-10-03 04:00:00+00:00 with 140.0 shares, remaining balance: $84820.87
# Exited FSLR at 145.35 on 2023-10-05 04:00:00+00:00 due to trailing stop, new balance: $105169.87
# Entered BIIB at 258.0 on 2023-10-04 04:00:00+00:00 with 81.0 shares, remaining balance: $84271.87
# Updated trailing stop for BIIB to $268.51
# Exited BIIB at 263.25 on 2023-10-06 04:00:00+00:00 due to trailing stop, new balance: $105595.12
# Entered GILD at 74.46 on 2023-10-05 04:00:00+00:00 with 283.0 shares, remaining balance: $84522.94
# Updated trailing stop for GILD to $76.56
# Exited GILD at 75.06 on 2023-10-09 04:00:00+00:00 due to trailing stop, new balance: $105764.92
# Entered TMUS at 139.27 on 2023-10-06 04:00:00+00:00 with 151.0 shares, remaining balance: $84735.15
# Updated trailing stop for TMUS to $145.26
# Exited TMUS at 142.41 on 2023-10-10 04:00:00+00:00 due to trailing stop, new balance: $106239.06
# Entered AMD at 108.4 on 2023-10-11 04:00:00+00:00 with 196.0 shares, remaining balance: $84992.66
# Exited AMD at 105.09 on 2023-10-13 04:00:00+00:00 due to trailing stop, new balance: $105590.30
# Entered INTC at 36.14 on 2023-10-13 04:00:00+00:00 with 584.0 shares, remaining balance: $84484.54
# Exited INTC at 36.06 on 2023-10-17 04:00:00+00:00 due to trailing stop, new balance: $105543.58
# Entered DIS at 85.345 on 2023-10-16 04:00:00+00:00 with 247.0 shares, remaining balance: $84463.36
# Exited DIS at 84.68 on 2023-10-18 04:00:00+00:00 due to trailing stop, new balance: $105379.32
# Entered ROKU at 59.58 on 2023-10-20 04:00:00+00:00 with 353.0 shares, remaining balance: $84347.58
# Updated trailing stop for ROKU to $62.65
# Exited ROKU at 61.42 on 2023-10-24 04:00:00+00:00 due to trailing stop, new balance: $106028.85
# Entered RY at 80.48 on 2023-10-20 04:00:00+00:00 with 263.0 shares, remaining balance: $84862.60
# Exited RY at 80.39 on 2023-10-24 04:00:00+00:00 due to trailing stop, new balance: $106005.17
# Entered TSM at 89.98 on 2023-10-20 04:00:00+00:00 with 235.0 shares, remaining balance: $84859.87
# Updated trailing stop for TSM to $93.47
# Exited TSM at 91.64 on 2023-10-24 04:00:00+00:00 due to trailing stop, new balance: $106395.27
# Entered TQQQ at 33.675 on 2023-10-20 04:00:00+00:00 with 631.0 shares, remaining balance: $85146.35
# Updated trailing stop for TQQQ to $34.48
# Exited TQQQ at 35.36 on 2023-10-24 04:00:00+00:00 due to take profit, new balance: $107458.51
# Entered ZM at 61.49 on 2023-10-23 04:00:00+00:00 with 349.0 shares, remaining balance: $85998.50
# Exited ZM at 60.35 on 2023-10-25 04:00:00+00:00 due to trailing stop, new balance: $107060.65
# Entered MMM at 90.11 on 2023-10-23 04:00:00+00:00 with 237.0 shares, remaining balance: $85704.58
# Exited MMM at 89.39 on 2023-10-25 04:00:00+00:00 due to trailing stop, new balance: $106890.01
# Entered VZ at 33.84 on 2023-10-27 04:00:00+00:00 with 631.0 shares, remaining balance: $85536.97
# Updated trailing stop for VZ to $35.83
# Exited VZ at 35.13 on 2023-10-31 04:00:00+00:00 due to trailing stop, new balance: $107704.00
# Entered HON at 177.54 on 2023-10-27 04:00:00+00:00 with 121.0 shares, remaining balance: $86221.66
# Updated trailing stop for HON to $186.93
# Exited HON at 183.26 on 2023-10-31 04:00:00+00:00 due to trailing stop, new balance: $108396.12
# Entered AMZN at 132.75 on 2023-10-30 04:00:00+00:00 with 163.0 shares, remaining balance: $86757.87
# Updated trailing stop for AMZN to $139.74
# Exited AMZN at 137.0 on 2023-11-01 04:00:00+00:00 due to trailing stop, new balance: $109088.87
# Entered JPM at 137.71 on 2023-10-30 04:00:00+00:00 with 158.0 shares, remaining balance: $87330.69
# Updated trailing stop for JPM to $141.72
# Exited JPM at 138.94 on 2023-11-01 04:00:00+00:00 due to trailing stop, new balance: $109283.21
# Entered NVDA at 408.84 on 2023-10-31 04:00:00+00:00 with 53.0 shares, remaining balance: $87614.69
# Updated trailing stop for NVDA to $443.76
# Exited NVDA at 435.06 on 2023-11-02 04:00:00+00:00 due to trailing stop, new balance: $110672.87
# Entered PYPL at 55.05 on 2023-11-01 04:00:00+00:00 with 402.0 shares, remaining balance: $88542.77
# Updated trailing stop for PYPL to $57.22
# Exited PYPL at 56.1 on 2023-11-03 04:00:00+00:00 due to trailing stop, new balance: $111094.97
# Entered SQ at 43.71 on 2023-11-01 04:00:00+00:00 with 508.0 shares, remaining balance: $88890.29
# Updated trailing stop for SQ to $49.65
# Exited SQ at 48.68 on 2023-11-03 04:00:00+00:00 due to trailing stop, new balance: $113619.73
# Entered MSFT at 353.45 on 2023-11-03 04:00:00+00:00 with 64.0 shares, remaining balance: $90998.93
# Updated trailing stop for MSFT to $367.74
# Exited MSFT at 360.53 on 2023-11-07 05:00:00+00:00 due to trailing stop, new balance: $114072.85
# Entered CAT at 234.58 on 2023-11-06 05:00:00+00:00 with 97.0 shares, remaining balance: $91318.59
# Updated trailing stop for CAT to $239.52
# Exited CAT at 234.82 on 2023-11-08 05:00:00+00:00 due to trailing stop, new balance: $114096.13
# Entered INTC at 38.24 on 2023-11-06 05:00:00+00:00 with 596.0 shares, remaining balance: $91305.09
# Exited INTC at 37.92 on 2023-11-08 05:00:00+00:00 due to trailing stop, new balance: $113905.41
# Entered DIS at 84.155 on 2023-11-06 05:00:00+00:00 with 270.0 shares, remaining balance: $91183.56
# Updated trailing stop for DIS to $86.19
# Exited DIS at 84.5 on 2023-11-08 05:00:00+00:00 due to trailing stop, new balance: $113998.56
# Entered ABBV at 138.59 on 2023-11-10 05:00:00+00:00 with 164.0 shares, remaining balance: $91269.80
# Exited ABBV at 138.06 on 2023-11-14 05:00:00+00:00 due to trailing stop, new balance: $113911.64
# Entered INTC at 38.8 on 2023-11-13 05:00:00+00:00 with 587.0 shares, remaining balance: $91136.04
# Updated trailing stop for INTC to $41.42
# Exited INTC at 40.61 on 2023-11-15 05:00:00+00:00 due to trailing stop, new balance: $114974.11
# Entered TGT at 126.08 on 2023-11-14 05:00:00+00:00 with 182.0 shares, remaining balance: $92027.55
# Updated trailing stop for TGT to $132.54
# Exited TGT at 129.94 on 2023-11-16 05:00:00+00:00 due to trailing stop, new balance: $115676.63
# Entered FSLR at 155.0 on 2023-11-17 05:00:00+00:00 with 149.0 shares, remaining balance: $92581.63
# Updated trailing stop for FSLR to $161.77
# Exited FSLR at 158.6 on 2023-11-21 05:00:00+00:00 due to trailing stop, new balance: $116213.03
# Entered SQ at 57.92 on 2023-11-17 05:00:00+00:00 with 401.0 shares, remaining balance: $92987.11
# Updated trailing stop for SQ to $59.84
# Exited SQ at 58.67 on 2023-11-21 05:00:00+00:00 due to trailing stop, new balance: $116513.78
# Entered BABA at 76.91 on 2023-11-17 05:00:00+00:00 with 302.0 shares, remaining balance: $93286.96
# Updated trailing stop for BABA to $80.52
# Exited BABA at 78.94 on 2023-11-21 05:00:00+00:00 due to trailing stop, new balance: $117126.84
# Entered GS at 336.94 on 2023-11-21 05:00:00+00:00 with 69.0 shares, remaining balance: $93877.98
# Updated trailing stop for GS to $345.93
# Exited GS at 339.15 on 2023-11-24 05:00:00+00:00 due to trailing stop, new balance: $117279.33
# Entered DIS at 94.9 on 2023-11-22 05:00:00+00:00 with 247.0 shares, remaining balance: $93839.03
# Updated trailing stop for DIS to $97.07
# Exited DIS at 95.17 on 2023-11-27 05:00:00+00:00 due to trailing stop, new balance: $117346.02
# Entered ENPH at 97.11 on 2023-11-27 05:00:00+00:00 with 241.0 shares, remaining balance: $93942.51
# Updated trailing stop for ENPH to $102.98
# Exited ENPH at 100.96 on 2023-11-29 05:00:00+00:00 due to trailing stop, new balance: $118273.87
# Entered AMD at 121.98 on 2023-11-27 05:00:00+00:00 with 193.0 shares, remaining balance: $94731.73
# Updated trailing stop for AMD to $126.33
# Exited AMD at 123.85 on 2023-11-29 05:00:00+00:00 due to trailing stop, new balance: $118634.78
# Entered RY at 88.6 on 2023-11-29 05:00:00+00:00 with 267.0 shares, remaining balance: $94978.58
# Updated trailing stop for RY to $92.91
# Exited RY at 91.09 on 2023-12-01 05:00:00+00:00 due to trailing stop, new balance: $119299.61
# Entered JNJ at 158.0 on 2023-12-01 05:00:00+00:00 with 151.0 shares, remaining balance: $95441.61
# Updated trailing stop for JNJ to $161.72
# Exited JNJ at 158.55 on 2023-12-05 05:00:00+00:00 due to trailing stop, new balance: $119382.66
# Entered TSM at 97.96 on 2023-12-06 05:00:00+00:00 with 243.0 shares, remaining balance: $95578.38
# Updated trailing stop for TSM to $102.36
# Exited TSM at 100.35 on 2023-12-08 05:00:00+00:00 due to trailing stop, new balance: $119963.43
# Entered CVX at 143.51 on 2023-12-07 05:00:00+00:00 with 167.0 shares, remaining balance: $95997.26
# Updated trailing stop for CVX to $147.24
# Exited CVX at 144.35 on 2023-12-11 05:00:00+00:00 due to trailing stop, new balance: $120103.71
# Entered TROW at 98.15 on 2023-12-08 05:00:00+00:00 with 244.0 shares, remaining balance: $96155.11
# Updated trailing stop for TROW to $101.35
# Exited TROW at 99.36 on 2023-12-12 05:00:00+00:00 due to trailing stop, new balance: $120398.95
# Entered BIIB at 247.55 on 2023-12-11 05:00:00+00:00 with 97.0 shares, remaining balance: $96386.60
# Updated trailing stop for BIIB to $260.67
# Exited BIIB at 255.56 on 2023-12-13 05:00:00+00:00 due to trailing stop, new balance: $121175.92
# Entered VZ at 37.25 on 2023-12-13 05:00:00+00:00 with 650.0 shares, remaining balance: $96963.42
# Updated trailing stop for VZ to $38.12
# Exited VZ at 37.37 on 2023-12-15 05:00:00+00:00 due to trailing stop, new balance: $121253.92
# Entered TQQQ at 48.94 on 2023-12-14 05:00:00+00:00 with 495.0 shares, remaining balance: $97028.62
# Updated trailing stop for TQQQ to $49.01
# Exited TQQQ at 50.27 on 2023-12-18 05:00:00+00:00 due to take profit, new balance: $121912.27
# Entered HD at 348.22 on 2023-12-14 05:00:00+00:00 with 70.0 shares, remaining balance: $97536.87
# Updated trailing stop for HD to $357.83
# Exited HD at 350.81 on 2023-12-18 05:00:00+00:00 due to trailing stop, new balance: $122093.57
# Entered COIN at 144.81 on 2023-12-15 05:00:00+00:00 with 168.0 shares, remaining balance: $97765.49
# Updated trailing stop for COIN to $164.38
# Exited COIN at 161.16 on 2023-12-19 05:00:00+00:00 due to trailing stop, new balance: $124840.37
# Entered XOM at 102.0 on 2023-12-18 05:00:00+00:00 with 244.0 shares, remaining balance: $99952.37
# Exited XOM at 101.27 on 2023-12-20 05:00:00+00:00 due to trailing stop, new balance: $124662.25
# Entered ARKK at 51.52 on 2023-12-18 05:00:00+00:00 with 483.0 shares, remaining balance: $99778.09
# Updated trailing stop for ARKK to $51.00
# Exited ARKK at 52.31 on 2023-12-21 05:00:00+00:00 due to Day 3 Exit, new balance: $125043.82
# Entered MS at 90.915 on 2023-12-18 05:00:00+00:00 with 275.0 shares, remaining balance: $100042.19
# Updated trailing stop for MS to $92.96
# Exited MS at 91.14 on 2023-12-20 05:00:00+00:00 due to trailing stop, new balance: $125105.69
# Entered DIS at 90.84 on 2023-12-22 05:00:00+00:00 with 275.0 shares, remaining balance: $100124.69
# Exited DIS at 90.38 on 2023-12-27 05:00:00+00:00 due to trailing stop, new balance: $124979.19
# Entered C at 50.88 on 2023-12-22 05:00:00+00:00 with 491.0 shares, remaining balance: $99997.11
# Updated trailing stop for C to $52.49
# Exited C at 51.46 on 2023-12-27 05:00:00+00:00 due to trailing stop, new balance: $125263.97
# Entered RIO at 74.0 on 2023-12-22 05:00:00+00:00 with 338.0 shares, remaining balance: $100251.97
# Updated trailing stop for RIO to $76.27
# Exited RIO at 74.77 on 2023-12-27 05:00:00+00:00 due to trailing stop, new balance: $125524.23
# Entered TGT at 140.93 on 2023-12-26 05:00:00+00:00 with 178.0 shares, remaining balance: $100438.69
# Updated trailing stop for TGT to $145.39
# Exited TGT at 142.54 on 2023-12-28 05:00:00+00:00 due to trailing stop, new balance: $125810.81
# Entered GOOG at 138.6 on 2024-01-02 05:00:00+00:00 with 181.0 shares, remaining balance: $100724.21
# Exited GOOG at 138.04 on 2024-01-04 05:00:00+00:00 due to trailing stop, new balance: $125709.45
# Entered RY at 100.0 on 2024-01-02 05:00:00+00:00 with 251.0 shares, remaining balance: $100609.45
# Updated trailing stop for RY to $102.17
# Exited RY at 100.17 on 2024-01-04 05:00:00+00:00 due to trailing stop, new balance: $125752.12
# Entered AMD at 134.3 on 2024-01-03 05:00:00+00:00 with 187.0 shares, remaining balance: $100638.02
# Updated trailing stop for AMD to $141.35
# Exited AMD at 138.58 on 2024-01-05 05:00:00+00:00 due to trailing stop, new balance: $126552.48
# Entered AMD at 136.78 on 2024-01-04 05:00:00+00:00 with 185.0 shares, remaining balance: $101248.18
# Updated trailing stop for AMD to $149.10
# Exited AMD at 146.18 on 2024-01-08 05:00:00+00:00 due to trailing stop, new balance: $128291.48
# Entered SPY at 471.87 on 2024-01-08 05:00:00+00:00 with 54.0 shares, remaining balance: $102810.50
# Updated trailing stop for SPY to $464.65
# Updated trailing stop for SPY to $464.65
# Exited SPY at 476.35 on 2024-01-11 05:00:00+00:00 due to Day 3 Exit, new balance: $128533.40
# Entered PYPL at 60.95 on 2024-01-09 05:00:00+00:00 with 421.0 shares, remaining balance: $102873.45
# Updated trailing stop for PYPL to $62.58
# Exited PYPL at 61.35 on 2024-01-11 05:00:00+00:00 due to trailing stop, new balance: $128701.80
# Entered NKE at 102.69 on 2024-01-09 05:00:00+00:00 with 250.0 shares, remaining balance: $103029.30
# Updated trailing stop for NKE to $108.02
# Exited NKE at 105.9 on 2024-01-11 05:00:00+00:00 due to trailing stop, new balance: $129504.30
# Entered NKE at 104.22 on 2024-01-10 05:00:00+00:00 with 248.0 shares, remaining balance: $103657.74
# Updated trailing stop for NKE to $107.16
# Exited NKE at 105.06 on 2024-01-12 05:00:00+00:00 due to trailing stop, new balance: $129712.62
# Entered SAP at 156.82 on 2024-01-16 05:00:00+00:00 with 165.0 shares, remaining balance: $103837.32
# Updated trailing stop for SAP to $163.64
# Exited SAP at 160.43 on 2024-01-18 05:00:00+00:00 due to trailing stop, new balance: $130308.27
# Entered SAP at 159.01 on 2024-01-17 05:00:00+00:00 with 163.0 shares, remaining balance: $104389.64
# Updated trailing stop for SAP to $166.72
# Exited SAP at 163.45 on 2024-01-19 05:00:00+00:00 due to trailing stop, new balance: $131031.99
# Entered SBUX at 93.18 on 2024-01-18 05:00:00+00:00 with 281.0 shares, remaining balance: $104848.41
# Exited SBUX at 93.07 on 2024-01-22 05:00:00+00:00 due to trailing stop, new balance: $131001.08
# Entered NKE at 101.02 on 2024-01-18 05:00:00+00:00 with 259.0 shares, remaining balance: $104836.90
# Exited NKE at 100.56 on 2024-01-22 05:00:00+00:00 due to trailing stop, new balance: $130881.94
# Entered META at 394.985 on 2024-01-26 05:00:00+00:00 with 66.0 shares, remaining balance: $104812.93
# Updated trailing stop for META to $408.06
# Exited META at 400.06 on 2024-01-30 05:00:00+00:00 due to trailing stop, new balance: $131216.89
# Entered MU at 84.957 on 2024-01-30 05:00:00+00:00 with 308.0 shares, remaining balance: $105050.14
# Updated trailing stop for MU to $87.32
# Exited MU at 85.61 on 2024-02-01 05:00:00+00:00 due to trailing stop, new balance: $131418.02
# Entered SBUX at 93.1 on 2024-01-31 05:00:00+00:00 with 282.0 shares, remaining balance: $105163.82
# Exited SBUX at 92.99 on 2024-02-02 05:00:00+00:00 due to trailing stop, new balance: $131387.00
# Entered MU at 85.07 on 2024-02-01 05:00:00+00:00 with 308.0 shares, remaining balance: $105185.44
# Updated trailing stop for MU to $88.72
# Exited MU at 86.98 on 2024-02-05 05:00:00+00:00 due to trailing stop, new balance: $131975.28
# Entered SAP at 176.28 on 2024-02-02 05:00:00+00:00 with 149.0 shares, remaining balance: $105709.56
# Updated trailing stop for SAP to $182.37
# Exited SAP at 178.79 on 2024-02-06 05:00:00+00:00 due to trailing stop, new balance: $132349.27
# Entered MS at 85.685 on 2024-02-08 05:00:00+00:00 with 308.0 shares, remaining balance: $105958.29
# Updated trailing stop for MS to $88.61
# Exited MS at 86.87 on 2024-02-12 05:00:00+00:00 due to trailing stop, new balance: $132714.25
# Entered AAPL at 188.65 on 2024-02-08 05:00:00+00:00 with 140.0 shares, remaining balance: $106303.25
# Exited AAPL at 187.15 on 2024-02-12 05:00:00+00:00 due to trailing stop, new balance: $132504.25
# Entered TROW at 106.09 on 2024-02-09 05:00:00+00:00 with 249.0 shares, remaining balance: $106087.84
# Exited TROW at 104.74 on 2024-02-13 05:00:00+00:00 due to trailing stop, new balance: $132168.10
# Entered TGT at 147.52 on 2024-02-09 05:00:00+00:00 with 179.0 shares, remaining balance: $105762.02
# Exited TGT at 146.11 on 2024-02-13 05:00:00+00:00 due to trailing stop, new balance: $131915.71
# Entered SQ at 67.02 on 2024-02-09 05:00:00+00:00 with 393.0 shares, remaining balance: $105576.85
# Exited SQ at 64.98 on 2024-02-13 05:00:00+00:00 due to trailing stop, new balance: $131113.99
# Entered QCOM at 155.0 on 2024-02-14 05:00:00+00:00 with 169.0 shares, remaining balance: $104918.99
# Exited QCOM at 152.69 on 2024-02-16 05:00:00+00:00 due to trailing stop, new balance: $130723.60
# Entered SAP at 175.36 on 2024-02-20 05:00:00+00:00 with 149.0 shares, remaining balance: $104594.96
# Updated trailing stop for SAP to $185.32
# Exited SAP at 181.69 on 2024-02-22 05:00:00+00:00 due to trailing stop, new balance: $131666.77
# Entered MU at 85.0 on 2024-02-21 05:00:00+00:00 with 309.0 shares, remaining balance: $105401.77
# Updated trailing stop for MU to $87.72
# Exited MU at 86.0 on 2024-02-23 05:00:00+00:00 due to trailing stop, new balance: $131975.77
# Entered ETSY at 70.5 on 2024-02-22 05:00:00+00:00 with 374.0 shares, remaining balance: $105608.77
# Updated trailing stop for ETSY to $73.40
# Exited ETSY at 71.96 on 2024-02-26 05:00:00+00:00 due to trailing stop, new balance: $132521.81
# Entered SHOP at 75.05 on 2024-02-22 05:00:00+00:00 with 353.0 shares, remaining balance: $106029.16
# Updated trailing stop for SHOP to $79.11
# Exited SHOP at 77.56 on 2024-02-26 05:00:00+00:00 due to trailing stop, new balance: $133407.84
# Entered GE at 155.99 on 2024-02-28 05:00:00+00:00 with 171.0 shares, remaining balance: $106733.55
# Updated trailing stop for GE to $161.82
# Exited GE at 158.65 on 2024-03-01 05:00:00+00:00 due to trailing stop, new balance: $133862.70
# Entered ROKU at 62.75 on 2024-03-06 05:00:00+00:00 with 426.0 shares, remaining balance: $107131.20
# Updated trailing stop for ROKU to $65.79
# Exited ROKU at 64.5 on 2024-03-08 05:00:00+00:00 due to trailing stop, new balance: $134608.20
# Entered GE at 162.04 on 2024-03-06 05:00:00+00:00 with 166.0 shares, remaining balance: $107709.56
# Updated trailing stop for GE to $171.32
# Exited GE at 167.96 on 2024-03-08 05:00:00+00:00 due to trailing stop, new balance: $135590.92
# Entered TXN at 172.28 on 2024-03-06 05:00:00+00:00 with 157.0 shares, remaining balance: $108542.96
# Updated trailing stop for TXN to $175.75
# Exited TXN at 172.3 on 2024-03-08 05:00:00+00:00 due to trailing stop, new balance: $135594.06
# Entered AAPL at 169.0 on 2024-03-07 05:00:00+00:00 with 160.0 shares, remaining balance: $108554.06
# Updated trailing stop for AAPL to $176.21
# Exited AAPL at 172.75 on 2024-03-11 04:00:00+00:00 due to trailing stop, new balance: $136194.06
# Entered WMT at 60.1 on 2024-03-08 05:00:00+00:00 with 453.0 shares, remaining balance: $108968.76
# Updated trailing stop for WMT to $62.64
# Exited WMT at 61.41 on 2024-03-12 04:00:00+00:00 due to trailing stop, new balance: $136787.49
# Entered TQQQ at 60.29 on 2024-03-11 04:00:00+00:00 with 453.0 shares, remaining balance: $109476.12
# Updated trailing stop for TQQQ to $58.93
# Exited TQQQ at 59.95 on 2024-03-14 04:00:00+00:00 due to Day 3 Exit, new balance: $136633.47
# Entered TSLA at 163.16 on 2024-03-14 04:00:00+00:00 with 167.0 shares, remaining balance: $109385.75
# Updated trailing stop for TSLA to $177.28
# Exited TSLA at 173.8 on 2024-03-18 04:00:00+00:00 due to trailing stop, new balance: $138410.35
# Entered AMD at 184.83 on 2024-03-14 04:00:00+00:00 with 149.0 shares, remaining balance: $110870.68
# Updated trailing stop for AMD to $194.46
# Exited AMD at 190.65 on 2024-03-18 04:00:00+00:00 due to trailing stop, new balance: $139277.53
# Entered DIS at 111.6 on 2024-03-14 04:00:00+00:00 with 249.0 shares, remaining balance: $111489.13
# Updated trailing stop for DIS to $116.13
# Exited DIS at 113.85 on 2024-03-18 04:00:00+00:00 due to trailing stop, new balance: $139837.78
# Entered BHP at 55.2 on 2024-03-14 04:00:00+00:00 with 506.0 shares, remaining balance: $111906.58
# Updated trailing stop for BHP to $57.00
# Exited BHP at 55.88 on 2024-03-18 04:00:00+00:00 due to trailing stop, new balance: $140181.86
# Entered TGT at 163.98 on 2024-03-15 04:00:00+00:00 with 170.0 shares, remaining balance: $112305.26
# Updated trailing stop for TGT to $171.57
# Exited TGT at 168.21 on 2024-03-19 04:00:00+00:00 due to trailing stop, new balance: $140900.96
# Entered SMH at 215.72 on 2024-03-18 04:00:00+00:00 with 130.0 shares, remaining balance: $112857.36
# Updated trailing stop for SMH to $215.76
# Exited SMH at 221.29 on 2024-03-20 04:00:00+00:00 due to take profit, new balance: $141625.06
# Entered RIO at 62.93 on 2024-03-19 04:00:00+00:00 with 450.0 shares, remaining balance: $113306.56
# Updated trailing stop for RIO to $65.41
# Exited RIO at 64.13 on 2024-03-21 04:00:00+00:00 due to trailing stop, new balance: $142165.06
# Entered QCOM at 170.74 on 2024-03-20 04:00:00+00:00 with 166.0 shares, remaining balance: $113822.22
# Exited QCOM at 170.1 on 2024-03-22 04:00:00+00:00 due to trailing stop, new balance: $142058.82
# Entered PFE at 27.45 on 2024-03-25 04:00:00+00:00 with 1035.0 shares, remaining balance: $113648.07
# Updated trailing stop for PFE to $28.34
# Exited PFE at 27.78 on 2024-03-27 04:00:00+00:00 due to trailing stop, new balance: $142400.37
# Entered TD at 59.93 on 2024-03-26 04:00:00+00:00 with 475.0 shares, remaining balance: $113933.62
# Updated trailing stop for TD to $61.59
# Exited TD at 60.38 on 2024-03-28 04:00:00+00:00 due to trailing stop, new balance: $142614.12
# Entered ZM at 63.51 on 2024-04-01 04:00:00+00:00 with 449.0 shares, remaining balance: $114098.13
# Exited ZM at 63.22 on 2024-04-03 04:00:00+00:00 due to trailing stop, new balance: $142483.91
# Entered ARKG at 27.0 on 2024-04-02 04:00:00+00:00 with 1055.0 shares, remaining balance: $113998.91
# Exited ARKG at 26.71 on 2024-04-05 04:00:00+00:00 due to Day 3 Exit, new balance: $142177.96
# Entered TXN at 169.58 on 2024-04-02 04:00:00+00:00 with 167.0 shares, remaining balance: $113858.10
# Exited TXN at 168.53 on 2024-04-04 04:00:00+00:00 due to trailing stop, new balance: $142002.61
# Entered SCHW at 71.48 on 2024-04-04 04:00:00+00:00 with 397.0 shares, remaining balance: $113625.05
# Updated trailing stop for SCHW to $73.82
# Exited SCHW at 72.37 on 2024-04-08 04:00:00+00:00 due to trailing stop, new balance: $142355.94
# Entered BABA at 72.37 on 2024-04-08 04:00:00+00:00 with 393.0 shares, remaining balance: $113914.53
# Updated trailing stop for BABA to $76.08
# Exited BABA at 74.59 on 2024-04-10 04:00:00+00:00 due to trailing stop, new balance: $143228.40
# Entered QCOM at 175.27 on 2024-04-08 04:00:00+00:00 with 163.0 shares, remaining balance: $114659.39
# Exited QCOM at 170.86 on 2024-04-10 04:00:00+00:00 due to trailing stop, new balance: $142509.57
# Entered BAC at 37.51 on 2024-04-08 04:00:00+00:00 with 759.0 shares, remaining balance: $114039.48
# Exited BAC at 36.65 on 2024-04-10 04:00:00+00:00 due to trailing stop, new balance: $141856.83
# Entered TSLA at 172.55 on 2024-04-10 04:00:00+00:00 with 164.0 shares, remaining balance: $113558.63
# Exited TSLA at 171.05 on 2024-04-12 04:00:00+00:00 due to trailing stop, new balance: $141610.83
# Entered GE at 152.7 on 2024-04-15 04:00:00+00:00 with 185.0 shares, remaining balance: $113361.33
# Updated trailing stop for GE to $158.78
# Exited GE at 155.67 on 2024-04-17 04:00:00+00:00 due to trailing stop, new balance: $142160.28
# Entered GOOG at 155.64 on 2024-04-15 04:00:00+00:00 with 182.0 shares, remaining balance: $113833.80
# Updated trailing stop for GOOG to $160.02
# Exited GOOG at 156.88 on 2024-04-17 04:00:00+00:00 due to trailing stop, new balance: $142385.96
# Entered WFC at 56.88 on 2024-04-16 04:00:00+00:00 with 500.0 shares, remaining balance: $113945.96
# Updated trailing stop for WFC to $59.91
# Exited WFC at 58.74 on 2024-04-18 04:00:00+00:00 due to trailing stop, new balance: $143315.96
# Entered ABBV at 164.15 on 2024-04-16 04:00:00+00:00 with 174.0 shares, remaining balance: $114753.86
# Updated trailing stop for ABBV to $167.95
# Exited ABBV at 164.66 on 2024-04-18 04:00:00+00:00 due to trailing stop, new balance: $143404.70
# Entered BA at 169.48 on 2024-04-17 04:00:00+00:00 with 169.0 shares, remaining balance: $114762.58
# Updated trailing stop for BA to $173.22
# Exited BA at 169.82 on 2024-04-19 04:00:00+00:00 due to trailing stop, new balance: $143462.16
# Entered WFC at 57.625 on 2024-04-17 04:00:00+00:00 with 497.0 shares, remaining balance: $114822.53
# Updated trailing stop for WFC to $61.56
# Exited WFC at 60.35 on 2024-04-19 04:00:00+00:00 due to trailing stop, new balance: $144816.48
# Entered CVX at 157.14 on 2024-04-17 04:00:00+00:00 with 184.0 shares, remaining balance: $115902.72
# Updated trailing stop for CVX to $163.20
# Exited CVX at 160.0 on 2024-04-19 04:00:00+00:00 due to trailing stop, new balance: $145342.72
# Entered TD at 57.32 on 2024-04-18 04:00:00+00:00 with 507.0 shares, remaining balance: $116281.48
# Updated trailing stop for TD to $59.73
# Exited TD at 58.56 on 2024-04-22 04:00:00+00:00 due to trailing stop, new balance: $145971.40
# Entered CHWY at 16.0 on 2024-04-18 04:00:00+00:00 with 1824.0 shares, remaining balance: $116787.40
# Exited CHWY at 15.7 on 2024-04-22 04:00:00+00:00 due to trailing stop, new balance: $145424.20
# Entered AAPL at 165.35 on 2024-04-22 04:00:00+00:00 with 175.0 shares, remaining balance: $116487.95
# Updated trailing stop for AAPL to $172.40
# Exited AAPL at 169.02 on 2024-04-24 04:00:00+00:00 due to trailing stop, new balance: $146066.45
# Entered V at 274.01 on 2024-04-22 04:00:00+00:00 with 106.0 shares, remaining balance: $117021.39
# Updated trailing stop for V to $280.52
# Exited V at 275.02 on 2024-04-24 04:00:00+00:00 due to trailing stop, new balance: $146173.51
# Entered TD at 59.26 on 2024-04-26 04:00:00+00:00 with 493.0 shares, remaining balance: $116958.33
# Updated trailing stop for TD to $60.51
# Exited TD at 59.32 on 2024-04-30 04:00:00+00:00 due to trailing stop, new balance: $146203.09
# Entered GE at 165.12 on 2024-05-03 04:00:00+00:00 with 177.0 shares, remaining balance: $116976.85
# Updated trailing stop for GE to $172.16
# Exited GE at 168.78 on 2024-05-07 04:00:00+00:00 due to trailing stop, new balance: $146850.91
# Entered ZM at 61.96 on 2024-05-06 04:00:00+00:00 with 474.0 shares, remaining balance: $117481.87
# Exited ZM at 61.23 on 2024-05-08 04:00:00+00:00 due to trailing stop, new balance: $146504.89
# Entered CAT at 340.0 on 2024-05-07 04:00:00+00:00 with 86.0 shares, remaining balance: $117264.89
# Updated trailing stop for CAT to $358.82
# Exited CAT at 351.78 on 2024-05-09 04:00:00+00:00 due to trailing stop, new balance: $147517.97
# Entered SAP at 189.7 on 2024-05-09 04:00:00+00:00 with 155.0 shares, remaining balance: $118114.47
# Updated trailing stop for SAP to $193.76
# Exited SAP at 189.96 on 2024-05-13 04:00:00+00:00 due to trailing stop, new balance: $147558.27
# Entered LLY at 751.52 on 2024-05-13 04:00:00+00:00 with 39.0 shares, remaining balance: $118248.99
# Updated trailing stop for LLY to $802.76
# Exited LLY at 787.02 on 2024-05-15 04:00:00+00:00 due to trailing stop, new balance: $148942.77
# Entered WFC at 62.2 on 2024-05-14 04:00:00+00:00 with 478.0 shares, remaining balance: $119211.17
# Exited WFC at 61.06 on 2024-05-16 04:00:00+00:00 due to trailing stop, new balance: $148397.85
# Entered HD at 345.18 on 2024-05-14 04:00:00+00:00 with 85.0 shares, remaining balance: $119057.55
# Exited HD at 342.73 on 2024-05-16 04:00:00+00:00 due to trailing stop, new balance: $148189.60
# Entered AAPL at 189.51 on 2024-05-16 04:00:00+00:00 with 156.0 shares, remaining balance: $118626.04
# Updated trailing stop for AAPL to $194.86
# Exited AAPL at 191.04 on 2024-05-20 04:00:00+00:00 due to trailing stop, new balance: $148428.28
# Entered FCX at 54.0 on 2024-05-17 04:00:00+00:00 with 549.0 shares, remaining balance: $118782.28
# Updated trailing stop for FCX to $55.41
# Exited FCX at 54.32 on 2024-05-21 04:00:00+00:00 due to trailing stop, new balance: $148603.96
# Entered ROKU at 56.42 on 2024-05-23 04:00:00+00:00 with 526.0 shares, remaining balance: $118927.04
# Updated trailing stop for ROKU to $57.58
# Exited ROKU at 56.45 on 2024-05-28 04:00:00+00:00 due to trailing stop, new balance: $148619.74
# Entered XOM at 113.52 on 2024-05-24 04:00:00+00:00 with 261.0 shares, remaining balance: $118991.02
# Updated trailing stop for XOM to $115.90
# Exited XOM at 113.63 on 2024-05-29 04:00:00+00:00 due to trailing stop, new balance: $148648.45
# Entered CMCSA at 38.23 on 2024-05-24 04:00:00+00:00 with 777.0 shares, remaining balance: $118943.74
# Exited CMCSA at 37.94 on 2024-05-29 04:00:00+00:00 due to trailing stop, new balance: $148423.12
# Entered LOW at 213.63 on 2024-05-28 04:00:00+00:00 with 138.0 shares, remaining balance: $118942.18
# Updated trailing stop for LOW to $219.77
# Exited LOW at 215.46 on 2024-05-30 04:00:00+00:00 due to trailing stop, new balance: $148675.66
# Entered SHOP at 57.55 on 2024-05-28 04:00:00+00:00 with 516.0 shares, remaining balance: $118979.86
# Updated trailing stop for SHOP to $59.71
# Exited SHOP at 58.54 on 2024-05-30 04:00:00+00:00 due to trailing stop, new balance: $149186.50
# Entered WFC at 58.82 on 2024-05-29 04:00:00+00:00 with 507.0 shares, remaining balance: $119364.76
# Updated trailing stop for WFC to $61.12
# Exited WFC at 59.92 on 2024-05-31 04:00:00+00:00 due to trailing stop, new balance: $149744.20
# Entered SHOP at 58.8 on 2024-05-30 04:00:00+00:00 with 509.0 shares, remaining balance: $119815.00
# Updated trailing stop for SHOP to $60.89
# Exited SHOP at 59.7 on 2024-06-03 04:00:00+00:00 due to trailing stop, new balance: $150202.30
# Entered BHP at 59.03 on 2024-05-31 04:00:00+00:00 with 508.0 shares, remaining balance: $120215.06
# Exited BHP at 58.07 on 2024-06-04 04:00:00+00:00 due to trailing stop, new balance: $149714.62
# Entered CVX at 155.72 on 2024-06-03 04:00:00+00:00 with 192.0 shares, remaining balance: $119816.38
# Exited CVX at 154.98 on 2024-06-05 04:00:00+00:00 due to trailing stop, new balance: $149572.54
# Entered FSLR at 268.165 on 2024-06-04 04:00:00+00:00 with 111.0 shares, remaining balance: $119806.23
# Updated trailing stop for FSLR to $278.92
# Exited FSLR at 273.45 on 2024-06-06 04:00:00+00:00 due to trailing stop, new balance: $150159.18
# Entered HON at 207.93 on 2024-06-04 04:00:00+00:00 with 144.0 shares, remaining balance: $120217.26
# Updated trailing stop for HON to $212.62
# Exited HON at 208.45 on 2024-06-06 04:00:00+00:00 due to trailing stop, new balance: $150234.06
# Entered BA at 188.83 on 2024-06-05 04:00:00+00:00 with 159.0 shares, remaining balance: $120210.09
# Updated trailing stop for BA to $194.04
# Exited BA at 190.24 on 2024-06-07 04:00:00+00:00 due to trailing stop, new balance: $150458.25
# Entered TD at 55.49 on 2024-06-06 04:00:00+00:00 with 542.0 shares, remaining balance: $120382.67
# Exited TD at 55.21 on 2024-06-10 04:00:00+00:00 due to trailing stop, new balance: $150306.49
# Entered ZM at 62.43 on 2024-06-07 04:00:00+00:00 with 481.0 shares, remaining balance: $120277.66
# Updated trailing stop for ZM to $64.11
# Exited ZM at 62.85 on 2024-06-11 04:00:00+00:00 due to trailing stop, new balance: $150508.51
# Entered TROW at 117.45 on 2024-06-11 04:00:00+00:00 with 256.0 shares, remaining balance: $120441.31
# Exited TROW at 116.57 on 2024-06-13 04:00:00+00:00 due to trailing stop, new balance: $150283.23
# Entered MSFT at 440.85 on 2024-06-12 04:00:00+00:00 with 68.0 shares, remaining balance: $120305.43
# Updated trailing stop for MSFT to $451.42
# Exited MSFT at 442.57 on 2024-06-14 04:00:00+00:00 due to trailing stop, new balance: $150400.19
# Entered DE at 368.18 on 2024-06-12 04:00:00+00:00 with 81.0 shares, remaining balance: $120577.61
# Updated trailing stop for DE to $385.56
# Exited DE at 378.0 on 2024-06-14 04:00:00+00:00 due to trailing stop, new balance: $151195.61
# Entered LULU at 305.12 on 2024-06-13 04:00:00+00:00 with 99.0 shares, remaining balance: $120988.73
# Updated trailing stop for LULU to $319.17
# Exited LULU at 312.91 on 2024-06-17 04:00:00+00:00 due to trailing stop, new balance: $151966.82
# Entered MMM at 100.5 on 2024-06-13 04:00:00+00:00 with 302.0 shares, remaining balance: $121615.82
# Updated trailing stop for MMM to $102.54
# Exited MMM at 100.53 on 2024-06-17 04:00:00+00:00 due to trailing stop, new balance: $151975.88
# Entered SQ at 61.81 on 2024-06-13 04:00:00+00:00 with 491.0 shares, remaining balance: $121627.17
# Updated trailing stop for SQ to $63.75
# Exited SQ at 62.5 on 2024-06-17 04:00:00+00:00 due to trailing stop, new balance: $152314.67
# Entered WFC at 57.205 on 2024-06-14 04:00:00+00:00 with 532.0 shares, remaining balance: $121881.61
# Updated trailing stop for WFC to $60.23
# Exited WFC at 59.05 on 2024-06-18 04:00:00+00:00 due to trailing stop, new balance: $153296.21
# Entered QQQ at 479.46 on 2024-06-14 04:00:00+00:00 with 63.0 shares, remaining balance: $123090.23
# Updated trailing stop for QQQ to $473.08
# Updated trailing stop for QQQ to $473.08
# Exited QQQ at 481.47 on 2024-06-20 04:00:00+00:00 due to Day 3 Exit, new balance: $153422.84
# Entered LULU at 304.28 on 2024-06-14 04:00:00+00:00 with 100.0 shares, remaining balance: $122994.84
# Updated trailing stop for LULU to $319.49
# Exited LULU at 313.23 on 2024-06-18 04:00:00+00:00 due to trailing stop, new balance: $154317.84
# Entered EBAY at 52.85 on 2024-06-17 04:00:00+00:00 with 583.0 shares, remaining balance: $123506.29
# Updated trailing stop for EBAY to $54.92
# Exited EBAY at 53.84 on 2024-06-20 04:00:00+00:00 due to trailing stop, new balance: $154895.01
# Entered PFE at 26.98 on 2024-06-17 04:00:00+00:00 with 1148.0 shares, remaining balance: $123921.97
# Updated trailing stop for PFE to $28.29
# Exited PFE at 27.74 on 2024-06-20 04:00:00+00:00 due to trailing stop, new balance: $155767.49
# Entered BAC at 39.56 on 2024-06-17 04:00:00+00:00 with 787.0 shares, remaining balance: $124633.77
# Updated trailing stop for BAC to $40.79
# Exited BAC at 39.99 on 2024-06-20 04:00:00+00:00 due to trailing stop, new balance: $156105.90
# Entered VRTX at 466.18 on 2024-06-18 04:00:00+00:00 with 66.0 shares, remaining balance: $125338.02
# Updated trailing stop for VRTX to $478.08
# Exited VRTX at 468.71 on 2024-06-21 04:00:00+00:00 due to trailing stop, new balance: $156272.88
# Entered FSLR at 260.0 on 2024-06-18 04:00:00+00:00 with 120.0 shares, remaining balance: $125072.88
# Exited FSLR at 258.87 on 2024-06-21 04:00:00+00:00 due to trailing stop, new balance: $156137.28
# Entered MRK at 127.39 on 2024-06-18 04:00:00+00:00 with 245.0 shares, remaining balance: $124926.73
# Updated trailing stop for MRK to $133.33
# Exited MRK at 130.72 on 2024-06-21 04:00:00+00:00 due to trailing stop, new balance: $156953.13
# Entered TD at 54.17 on 2024-06-21 04:00:00+00:00 with 579.0 shares, remaining balance: $125588.70
# Updated trailing stop for TD to $55.79
# Exited TD at 54.7 on 2024-06-25 04:00:00+00:00 due to trailing stop, new balance: $157260.00
# Entered EBAY at 53.54 on 2024-06-25 04:00:00+00:00 with 587.0 shares, remaining balance: $125832.02
# Exited EBAY at 53.05 on 2024-06-27 04:00:00+00:00 due to trailing stop, new balance: $156972.37
# Entered SHOP at 65.29 on 2024-06-26 04:00:00+00:00 with 480.0 shares, remaining balance: $125633.17
# Updated trailing stop for SHOP to $67.37
# Exited SHOP at 66.05 on 2024-06-28 04:00:00+00:00 due to trailing stop, new balance: $157337.17
# Entered REGN at 1039.51 on 2024-07-05 04:00:00+00:00 with 30.0 shares, remaining balance: $126151.87
# Updated trailing stop for REGN to $1075.11
# Exited REGN at 1054.03 on 2024-07-09 04:00:00+00:00 due to trailing stop, new balance: $157772.77
# Entered TD at 55.56 on 2024-07-08 04:00:00+00:00 with 567.0 shares, remaining balance: $126270.25
# Updated trailing stop for TD to $56.94
# Exited TD at 55.82 on 2024-07-10 04:00:00+00:00 due to trailing stop, new balance: $157920.19
# Entered VRTX at 491.33 on 2024-07-10 04:00:00+00:00 with 64.0 shares, remaining balance: $126475.07
# Exited VRTX at 488.74 on 2024-07-12 04:00:00+00:00 due to trailing stop, new balance: $157754.43
# Entered SQ at 67.81 on 2024-07-11 04:00:00+00:00 with 465.0 shares, remaining balance: $126222.78
# Updated trailing stop for SQ to $73.50
# Exited SQ at 72.06 on 2024-07-15 04:00:00+00:00 due to trailing stop, new balance: $159730.68
# Entered UNP at 230.6 on 2024-07-12 04:00:00+00:00 with 138.0 shares, remaining balance: $127907.88
# Updated trailing stop for UNP to $247.92
# Exited UNP at 243.06 on 2024-07-16 04:00:00+00:00 due to trailing stop, new balance: $161450.16
# Entered ZM at 57.64 on 2024-07-12 04:00:00+00:00 with 560.0 shares, remaining balance: $129171.76
# Updated trailing stop for ZM to $60.34
# Exited ZM at 59.16 on 2024-07-16 04:00:00+00:00 due to trailing stop, new balance: $162301.36
# Entered ROKU at 61.46 on 2024-07-12 04:00:00+00:00 with 528.0 shares, remaining balance: $129850.48
# Updated trailing stop for ROKU to $66.02
# Exited ROKU at 64.73 on 2024-07-16 04:00:00+00:00 due to trailing stop, new balance: $164027.92
# Entered CAT at 346.83 on 2024-07-15 04:00:00+00:00 with 94.0 shares, remaining balance: $131425.90
# Updated trailing stop for CAT to $364.96
# Exited CAT at 357.8 on 2024-07-17 04:00:00+00:00 due to trailing stop, new balance: $165059.10
# Entered ROKU at 55.51 on 2024-07-24 04:00:00+00:00 with 594.0 shares, remaining balance: $132086.16
# Updated trailing stop for ROKU to $60.22
# Exited ROKU at 59.04 on 2024-07-26 04:00:00+00:00 due to trailing stop, new balance: $167155.92
# Entered ROKU at 57.6 on 2024-07-30 04:00:00+00:00 with 580.0 shares, remaining balance: $133747.92
# Exited ROKU at 55.33 on 2024-08-01 04:00:00+00:00 due to trailing stop, new balance: $165839.32
# Entered MRK at 115.16 on 2024-08-01 04:00:00+00:00 with 288.0 shares, remaining balance: $132673.24
# Exited MRK at 112.31 on 2024-08-05 04:00:00+00:00 due to trailing stop, new balance: $165018.52
# Entered TQQQ at 49.33 on 2024-08-02 04:00:00+00:00 with 669.0 shares, remaining balance: $132016.75
# Updated trailing stop for TQQQ to $53.59
# Exited TQQQ at 54.96 on 2024-08-06 04:00:00+00:00 due to take profit, new balance: $168784.99
# Entered COIN at 191.99 on 2024-08-05 04:00:00+00:00 with 175.0 shares, remaining balance: $135186.74
# Exited COIN at 178.91 on 2024-08-07 04:00:00+00:00 due to trailing stop, new balance: $166495.99
# Entered TMUS at 189.86 on 2024-08-06 04:00:00+00:00 with 175.0 shares, remaining balance: $133270.49
# Updated trailing stop for TMUS to $197.48
# Exited TMUS at 193.61 on 2024-08-08 04:00:00+00:00 due to trailing stop, new balance: $167152.24
# Entered LULU at 238.14 on 2024-08-07 04:00:00+00:00 with 140.0 shares, remaining balance: $133812.64
# Updated trailing stop for LULU to $243.49
# Exited LULU at 238.72 on 2024-08-09 04:00:00+00:00 due to trailing stop, new balance: $167233.44
# Entered DIA at 395.07 on 2024-08-12 04:00:00+00:00 with 84.0 shares, remaining balance: $134047.56
# Updated trailing stop for DIA to $390.09
# Updated trailing stop for DIA to $395.73
# Exited DIA at 405.88 on 2024-08-15 04:00:00+00:00 due to take profit, new balance: $168141.48
# Entered V at 262.84 on 2024-08-14 04:00:00+00:00 with 127.0 shares, remaining balance: $134760.80
# Updated trailing stop for V to $272.73
# Exited V at 267.38 on 2024-08-16 04:00:00+00:00 due to trailing stop, new balance: $168718.06
# Entered ARKF at 27.49 on 2024-08-15 04:00:00+00:00 with 1227.0 shares, remaining balance: $134987.83
# Updated trailing stop for ARKF to $27.58
# Exited ARKF at 28.29 on 2024-08-19 04:00:00+00:00 due to take profit, new balance: $169699.66
# Entered BLK at 872.25 on 2024-08-15 04:00:00+00:00 with 38.0 shares, remaining balance: $136554.16
# Exited BLK at 870.21 on 2024-08-19 04:00:00+00:00 due to trailing stop, new balance: $169622.14
# Entered SQ at 64.47 on 2024-08-15 04:00:00+00:00 with 526.0 shares, remaining balance: $135710.92
# Updated trailing stop for SQ to $68.22
# Exited SQ at 66.88 on 2024-08-19 04:00:00+00:00 due to trailing stop, new balance: $170889.80
# Entered GOOG at 163.41 on 2024-08-15 04:00:00+00:00 with 209.0 shares, remaining balance: $136737.11
# Updated trailing stop for GOOG to $171.77
# Exited GOOG at 168.4 on 2024-08-19 04:00:00+00:00 due to trailing stop, new balance: $171932.71
# Entered WFC at 55.345 on 2024-08-16 04:00:00+00:00 with 621.0 shares, remaining balance: $137563.46
# Final portfolio value: $172618.91
# Return percentage: 72.62%
# Trade log:
# {'symbol': 'BABA', 'entry_date': Timestamp('2023-07-03 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2023-07-06 04:00:00+0000', tz='UTC'), 'profit_loss_pct': -0.16670635865682373, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'TQQQ', 'entry_date': Timestamp('2023-07-11 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2023-07-13 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 5.3311020798470095, 'exit_reason': 'Take Profit Hit'}
# {'symbol': 'JPM', 'entry_date': Timestamp('2023-07-12 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2023-07-14 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.7195696032279905, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'AXP', 'entry_date': Timestamp('2023-07-14 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2023-07-18 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 2.9489996530588614, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# ...
# {'symbol': 'WFC', 'entry_date': Timestamp('2024-04-17 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-04-19 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 4.728850325379612, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'CVX', 'entry_date': Timestamp('2024-04-17 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-04-19 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 1.8200330915107636, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'TD', 'entry_date': Timestamp('2024-04-18 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-04-22 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 2.163293789253318, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'CHWY', 'entry_date': Timestamp('2024-04-18 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-04-22 04:00:00+0000', tz='UTC'), 'profit_loss_pct': -1.8750000000000044, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'AAPL', 'entry_date': Timestamp('2024-04-22 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-04-24 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 2.2195343211369916, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'V', 'entry_date': Timestamp('2024-04-22 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-04-24 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.3685996861428382, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'TD', 'entry_date': Timestamp('2024-04-26 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-04-30 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.10124873439082396, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'GE', 'entry_date': Timestamp('2024-05-03 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-05-07 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 2.2165697674418583, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'ZM', 'entry_date': Timestamp('2024-05-06 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-05-08 04:00:00+0000', tz='UTC'), 'profit_loss_pct': -1.1781794706262168, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'CAT', 'entry_date': Timestamp('2024-05-07 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-05-09 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 3.464705882352933, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'SAP', 'entry_date': Timestamp('2024-05-09 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-05-13 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.13705851344228748, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'LLY', 'entry_date': Timestamp('2024-05-13 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-05-15 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 4.723759846710666, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'WFC', 'entry_date': Timestamp('2024-05-14 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-05-16 04:00:00+0000', tz='UTC'), 'profit_loss_pct': -1.832797427652734, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'HD', 'entry_date': Timestamp('2024-05-14 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-05-16 04:00:00+0000', tz='UTC'), 'profit_loss_pct': -0.7097746103482209, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'AAPL', 'entry_date': Timestamp('2024-05-16 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-05-20 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.8073452588253924, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'FCX', 'entry_date': Timestamp('2024-05-17 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-05-21 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.5925925925925931, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'ROKU', 'entry_date': Timestamp('2024-05-23 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-05-28 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.053172633817797126, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'XOM', 'entry_date': Timestamp('2024-05-24 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-05-29 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.09689922480620106, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'CMCSA', 'entry_date': Timestamp('2024-05-24 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-05-29 04:00:00+0000', tz='UTC'), 'profit_loss_pct': -0.7585665707559487, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'LOW', 'entry_date': Timestamp('2024-05-28 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-05-30 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.8566212610588458, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'SHOP', 'entry_date': Timestamp('2024-05-28 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-05-30 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 1.7202432667245908, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'WFC', 'entry_date': Timestamp('2024-05-29 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-05-31 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 1.8701122067324063, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'SHOP', 'entry_date': Timestamp('2024-05-30 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-03 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 1.5306122448979689, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'BHP', 'entry_date': Timestamp('2024-05-31 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-04 04:00:00+0000', tz='UTC'), 'profit_loss_pct': -1.6262917160765726, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'CVX', 'entry_date': Timestamp('2024-06-03 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-05 04:00:00+0000', tz='UTC'), 'profit_loss_pct': -0.47521191882867264, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'FSLR', 'entry_date': Timestamp('2024-06-04 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-06 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 1.9708015587418075, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'HON', 'entry_date': Timestamp('2024-06-04 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-06 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.250084162939442, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'BA', 'entry_date': Timestamp('2024-06-05 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-07 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.7467033839961852, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'TD', 'entry_date': Timestamp('2024-06-06 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-10 04:00:00+0000', tz='UTC'), 'profit_loss_pct': -0.5045954225986684, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'ZM', 'entry_date': Timestamp('2024-06-07 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-11 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.6727534839019729, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'TROW', 'entry_date': Timestamp('2024-06-11 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-13 04:00:00+0000', tz='UTC'), 'profit_loss_pct': -0.7492550021285735, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'MSFT', 'entry_date': Timestamp('2024-06-12 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-14 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.39015538164908026, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'DE', 'entry_date': Timestamp('2024-06-12 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-14 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 2.6671736650551345, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'LULU', 'entry_date': Timestamp('2024-06-13 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-17 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 2.5530938647089734, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'MMM', 'entry_date': Timestamp('2024-06-13 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-17 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.02985074626865785, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'SQ', 'entry_date': Timestamp('2024-06-13 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-17 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 1.1163242193819733, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'WFC', 'entry_date': Timestamp('2024-06-14 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-18 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 3.2252425487282563, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'QQQ', 'entry_date': Timestamp('2024-06-14 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-20 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.41922162432737825, 'exit_reason': 'Day 3 Exit'}
# {'symbol': 'LULU', 'entry_date': Timestamp('2024-06-14 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-18 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 2.9413697909820056, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'EBAY', 'entry_date': Timestamp('2024-06-17 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-20 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 1.8732261116367115, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'PFE', 'entry_date': Timestamp('2024-06-17 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-20 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 2.8169014084506965, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'BAC', 'entry_date': Timestamp('2024-06-17 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-20 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 1.0869565217391297, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'VRTX', 'entry_date': Timestamp('2024-06-18 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-21 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.542708824917408, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'FSLR', 'entry_date': Timestamp('2024-06-18 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-21 04:00:00+0000', tz='UTC'), 'profit_loss_pct': -0.43461538461538285, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'MRK', 'entry_date': Timestamp('2024-06-18 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-21 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 2.614019938770703, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'TD', 'entry_date': Timestamp('2024-06-21 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-25 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.9784013291489775, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'EBAY', 'entry_date': Timestamp('2024-06-25 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-27 04:00:00+0000', tz='UTC'), 'profit_loss_pct': -0.9152035861038512, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'SHOP', 'entry_date': Timestamp('2024-06-26 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-06-28 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 1.1640373717261308, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'REGN', 'entry_date': Timestamp('2024-07-05 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-07-09 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 1.3968119594809074, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'TD', 'entry_date': Timestamp('2024-07-08 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-07-10 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.4679625629949568, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'VRTX', 'entry_date': Timestamp('2024-07-10 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-07-12 04:00:00+0000', tz='UTC'), 'profit_loss_pct': -0.5271406183216931, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'SQ', 'entry_date': Timestamp('2024-07-11 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-07-15 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 6.267512166347146, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'UNP', 'entry_date': Timestamp('2024-07-12 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-07-16 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 5.403295750216829, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'ZM', 'entry_date': Timestamp('2024-07-12 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-07-16 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 2.637057598889653, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'ROKU', 'entry_date': Timestamp('2024-07-12 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-07-16 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 5.320533680442569, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'CAT', 'entry_date': Timestamp('2024-07-15 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-07-17 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 3.1629328489461774, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'ROKU', 'entry_date': Timestamp('2024-07-24 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-07-26 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 6.35921455593587, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'ROKU', 'entry_date': Timestamp('2024-07-30 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-08-01 04:00:00+0000', tz='UTC'), 'profit_loss_pct': -3.9409722222222276, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'MRK', 'entry_date': Timestamp('2024-08-01 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-08-05 04:00:00+0000', tz='UTC'), 'profit_loss_pct': -2.4748176450156256, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'TQQQ', 'entry_date': Timestamp('2024-08-02 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-08-06 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 11.412933306304486, 'exit_reason': 'Take Profit Hit'}
# {'symbol': 'COIN', 'entry_date': Timestamp('2024-08-05 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-08-07 04:00:00+0000', tz='UTC'), 'profit_loss_pct': -6.812854836189391, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'TMUS', 'entry_date': Timestamp('2024-08-06 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-08-08 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 1.9751395765300748, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'LULU', 'entry_date': Timestamp('2024-08-07 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-08-09 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 0.24355421180818532, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'DIA', 'entry_date': Timestamp('2024-08-12 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-08-15 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 2.7362239603108316, 'exit_reason': 'Take Profit Hit'}
# {'symbol': 'V', 'entry_date': Timestamp('2024-08-14 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-08-16 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 1.7272865621671056, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'ARKF', 'entry_date': Timestamp('2024-08-15 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-08-19 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 2.9101491451436914, 'exit_reason': 'Take Profit Hit'}
# {'symbol': 'BLK', 'entry_date': Timestamp('2024-08-15 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-08-19 04:00:00+0000', tz='UTC'), 'profit_loss_pct': -0.23387790197763986, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'SQ', 'entry_date': Timestamp('2024-08-15 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-08-19 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 3.738172793547381, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
# {'symbol': 'GOOG', 'entry_date': Timestamp('2024-08-15 04:00:00+0000', tz='UTC'), 'exit_date': Timestamp('2024-08-19 04:00:00+0000', tz='UTC'), 'profit_loss_pct': 3.053668686126926, 'exit_reason': 'Trailing Stop or Stop-Loss Hit'}
